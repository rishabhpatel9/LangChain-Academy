# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

#model = init_chat_model(model="gpt-5-nano")
model = init_chat_model(model="gemini-2.5-flash-lite")

# %%
response = model.invoke("What's the capital of the Moon?")

response

# %%
print(response.content)

# %%
from pprint import pprint

pprint(response.response_metadata)

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model="gpt-5-nano",
    # Kwargs passed to the model:
    temperature=1.0
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(model="claude-sonnet-4-5")

response = model.invoke("What's the capital of the Moon?")
print(response.content)

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# Failed to multipart ingest runs: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# That's a fun question! The Moon doesn't have a capital city in the way Earth does. It's a celestial body with no permanent human settlements, governments, or infrastructure like cities.
#
# So, to answer directly: **The Moon has no capital.**
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
agent = create_agent(model="claude-sonnet-4-5")

# %%
agent = create_agent("gpt-5-nano")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)
# Out:
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='e2579bb6-cc03-42ba-bb83-b7e5f55be408'),
#               AIMessage(content="That's a fun question! The Moon doesn't have a capital city in the way Earth does. It's a natural celestial body without any human settlements or organized governments to establish one.\n\nHowever, if we were to imagine a hypothetical capital, it would likely be a place of great historical significance for lunar exploration, or perhaps a location with unique geological features. But officially, there is no capital of the Moon.", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019c990a-c914-7b82-95d9-3c39df66c426-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 10, 'output_tokens': 86, 'total_tokens': 96, 'input_token_details': {'cache_read': 0}})]}

# %%
print(response['messages'][-1].content)
# Out:
# That's a fun question! The Moon doesn't have a capital city in the way Earth does. It's a natural celestial body without any human settlements or organized governments to establish one.
#
# However, if we were to imagine a hypothetical capital, it would likely be a place of great historical significance for lunar exploration, or perhaps a location with unique geological features. But officially, there is no capital of the Moon.

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='afe15192-8560-48e0-98b5-7b087e707895'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='005baf10-1dab-4811-b1b2-fd52c850f567', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='63d6987d-816b-46d1-acf5-645ed097a706'),
#               AIMessage(content='Ah, this is where things get a bit... imaginative!\n\n**Luna City is not a real place.** It\'s a fictional city that has appeared in various science fiction stories, books, and games. Because it\'s fictional, its description and characteristics can vary widely depending on the creator.\n\nHowever, when people talk about "Luna City," they often envision it as:\n\n*   **A Hub of Lunar Activity:** It\'s typically portrayed as the primary human settlement on the Moon, serving as a base for scientific research, resource extraction (like Helium-3), space tourism, and possibly even a launching point for further space exploration.\n*   **A Densely Populated Metropolis (for the Moon):** Compared to the desolate lunar surface, Luna City would be a bustling center of life. It might be a sprawling underground complex, a series of interconnected domes, or even a city built into lunar craters.\n*   **Technologically Advanced:** Given its location and purpose, Luna City would be a marvel of engineering and technology. Think advanced life support systems, efficient transportation, and possibly even artificial gravity.\n*   **A Symbol of Humanity\'s Reach:** It represents humanity\'s ability to colonize and thrive in extreme environments, pushing the boundaries of what\'s possible.\n*   **Often a Setting for Conflict or Drama:** In many stories, Luna City becomes the stage for political intrigue, resource wars, or the challenges of surviving in a harsh, alien environment.\n\n**Where might you have encountered "Luna City"?**\n\n*   **Video Games:** It\'s a common name for a lunar base in many space-themed video games.\n*   **Science Fiction Novels and Comics:** Authors often create their own versions of a lunar capital.\n*   **Movies and TV Shows:** While not always called "Luna City," lunar settlements are a recurring theme.\n\n**So, while it\'s a fascinating concept and a popular idea in fiction, there is no actual "capital of the Moon" or a real "Luna City" in existence today.** We have a few small research outposts and probes on the Moon, but nothing resembling a city.\n\nIf you encountered the name "Luna City" in a specific context (like a game or book), knowing that context might help me tell you more about *that particular version* of Luna City!', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019c990b-7ac0-7132-a2c7-1488143561c2-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 29, 'output_tokens': 484, 'total_tokens': 513, 'input_token_details': {'cache_read': 0}})]}
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# While the concept of a "Luna City" as the capital of the Moon is a popular staple of science fiction, it's important to understand that **Luna City does not exist in reality.** The Moon is currently uninhabited and has no established cities, let alone a capital.
#
# However, the idea of Luna City is rich with possibilities and has been explored in countless stories, games, and artistic visions. So, let's dive into what a "Luna City" *could* be like, drawing from these fictional representations:
#
# ## The Concept of Luna City: A Fictional Capital
#
# If Luna City were to exist, it would be a monumental achievement of human engineering, ingenuity, and adaptation. Here's a breakdown of what it might entail:
#
# **1. Location and Structure:**
#
# *   **Underground or Domed:** Given the harsh lunar environment (vacuum, extreme temperatures, radiation, micrometeoroids), Luna City would likely be either:
#     *   **Subterranean:** Built deep within lava tubes or excavated caverns for natural protection. This offers excellent shielding from radiation and temperature fluctuations.
#     *   **Surface Domes:** Constructed with advanced, transparent, and incredibly strong materials to create pressurized, breathable environments on the surface. These might be vast, interconnected domes.
# *   **Modular and Expandable:** To accommodate growth, the city would likely be designed in modules that can be added or reconfigured.
# *   **Resource Integration:** Structures would be built using in-situ resources (lunar regolith for 3D printing, water ice for life support and fuel) to minimize reliance on Earth.
#
# **2. Architecture and Design:**
#
# *   **Functional and Efficient:** Every aspect would be designed for practicality and survival. Aesthetics would likely be secondary to function, though there could be efforts to create pleasing and inspiring spaces.
# *   **Verticality:** To maximize space and create distinct zones, vertical architecture might be common, especially underground.
# *   **Biophilic Design (Potentially):** As a counterpoint to the sterile lunar environment, there might be intentional inclusion of plant life, green spaces, and natural light simulations to improve psychological well-being.
# *   **Redundancy and Safety:** Multiple layers of life support, power generation, and structural integrity would be paramount. Escape routes and emergency shelters would be standard.
#
# **3. Infrastructure and Technology:**
#
# *   **Advanced Life Support:** Sophisticated systems for air recycling, water purification, and waste management would be essential.
# *   **Power Generation:** Solar power would be a primary source, augmented by nuclear reactors or other advanced energy technologies. Energy storage would be critical for the lunar night.
# *   **Transportation:**
#     *   **Internal:** Pressurized maglev trains, electric vehicles, or even personal mobility devices within enclosed spaces.
#     *   **External:** Pressurized rovers, lunar surface vehicles, and potentially even small spacecraft for travel between settlements.
# *   **Communication:** Robust internal and external communication networks, likely employing advanced satellite and laser technologies.
# *   **Manufacturing and 3D Printing:** Extensive use of 3D printing for construction, tools, and even spare parts.
# *   **Agriculture:** Hydroponic or aeroponic farms would be vital for food production, possibly utilizing artificial light.
#
# **4. Governance and Society:**
#
# *   **Purpose-Driven:** Luna City would likely be founded for specific reasons: scientific research, resource extraction, a stepping stone for further space exploration, or as a refuge.
# *   **Strict Regulations:** Life on the Moon would necessitate strict adherence to rules for safety and resource conservation.
# *   **Specialized Population:** The initial inhabitants would be highly skilled scientists, engineers, technicians, and possibly miners or entrepreneurs.
# *   **Cultural Development:** Over time, a unique lunar culture could emerge, influenced by the shared experience of living in a challenging but awe-inspiring environment. Art, music, and traditions would likely reflect this.
# *   **Relationship with Earth:** This would be a crucial aspect. Luna City could be an independent entity, a colony, or a joint venture with Earth nations. The economic and political relationship would shape its development.
#
# **5. Challenges and Considerations:**
#
# *   **Psychological Impact:** The isolation, confinement, and alien environment could take a toll on mental health.
# *   **Resource Scarcity:** While lunar resources exist, their extraction and processing would be incredibly complex and energy-intensive.
# *   **Medical Care:** Specialized medical facilities and expertise would be required to deal with the unique health challenges of living in reduced gravity and a hostile environment.
# *   **Economic Viability:** Establishing a sustainable economy that can support a city would be a significant hurdle.
# *   **Defense and Security:** Protecting the city from external threats (accidents, potential future conflicts) would be a concern.
#
# **Fictional Portrayals of Luna City:**
#
# *   **"Moonbase Alpha" from *Space: 1999*:** A classic example of a lunar settlement, though its premise involved an accidental departure from the Moon.
# *   **Various Science Fiction Novels:** Authors like Arthur C. Clarke, Isaac Asimov, and Robert A. Heinlein have explored lunar bases and cities in their works, often depicting them as hubs of scientific advancement or industrial activity.
# *   **Video Games:** Games like *Destiny* feature a vibrant, albeit fictional, Luna City with its own lore and inhabitants.
#
# **In Conclusion:**
#
# While Luna City remains a figment of our collective imagination, its conceptualization allows us to explore the boundless possibilities of human ambition and our drive to push the boundaries of what's possible. It represents a future where humanity has not only reached for the stars but has begun to build a home among them. The "capital of the Moon" is a powerful symbol of our aspirations for a multi-planetary future.
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
